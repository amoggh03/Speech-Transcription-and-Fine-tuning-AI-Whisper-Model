# %%
! pip install -U accelerate
! pip install -U transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 22.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# ...

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-fa83825a-d664-c72a-df64-eddcbc5864c7)

# %%
# !add-apt-repository -y ppa:jonathonf//ffmpeg-4
# !apt update
# !apt install  -y ffmpeg
# Out:
# Unable to handle repository shortcut 'ppa:jonathonf//ffmpeg-4'
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [48.6 kB]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,046 kB]
# Get:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease [18.1 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,326 kB]
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# ...

# %%
# !pip install datasets>=2.6.1

# !pip install git+https://github.com/huggingface/transformers

# !pip install librosa

# !pip install jiwer

# !pip install evaluate>=0.30

# !pip install gradio
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-a0k4njuy
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-a0k4njuy
#   Resolved https://github.com/huggingface/transformers to commit 3cefac1d974db5e2825a0cb2b842883a628be7a0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for transformers: filename=transformers-4.37.0.dev0-py3-none-any.whl size=8281628 sha256=f5acf7b370dedd35f3595dbb78f7b980ca947e57a7eea80e01f5cc650262511e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-n5_c57o5/wheels/c0/14/d6/6c9a5582d2ac191ec0a483be151a4495fe1eb2a6706ca49f1b
# Successfully built transformers
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.36.2
#     Uninstalling transformers-4.36.2:
#       Successfully uninstalled transformers-4.36.2
# ...

# %%
from dataclasses import dataclass

from typing import Any, Dict, List, Union

import torch

# %%
###dont run
from huggingface_hub import HfApi, HfFolder
def login_hugging_face(token: str) -> None:
  api=HfApi()
  api.set_access_token(token)
  folder=HfFolder()
  folder.save_token(token)
  return None
token = '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'
login_hugging_face(token)
print("We are logged in to Hugging Face now!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-21c458699c76> in <cell line: 9>()
#       7   return None
#       8 token = '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'
# ----> 9 login_hugging_face(token)
#      10 print("We are logged in to Hugging Face now!")
#
# <ipython-input-10-21c458699c76> in login_hugging_face(token)
#       2 def login_hugging_face(token: str) -> None:
#       3   api=HfApi()
# ----> 4   api.set_access_token(token)
#       5   folder=HfFolder()
#       6   folder.save_token(token)
#
# AttributeError: 'HfApi' object has no attribute 'set_access_token'

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
from datasets import load_dataset, DatasetDict


common_voice=DatasetDict()

common_voice["train"]=load_dataset("mozilla-foundation/common_voice_11_0", "pa-IN", split="train+validation", use_auth_token=True)

common_voice["test"] = load_dataset("mozilla-foundation/common_voice_11_0", "pa-IN", split="test", use_auth_token=True)



common_voice = common_voice.remove_columns(["accent",

"age",

"client_id", "down_votes",

"gender",

"locale",

"path",

"segment",

"up_votes"])

print(common_voice)
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:2479: FutureWarning: 'use_auth_token' was deprecated in favor of 'token' in version 2.14.0 and will be removed in 3.0.0.
# You can remove this warning by passing 'token=<use_auth_token>' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1429: FutureWarning: The repository for mozilla-foundation/common_voice_11_0 contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/mozilla-foundation/common_voice_11_0
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 685it [00:00, 21629.40it/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# ...

# %%
from transformers import WhisperFeatureExtractor
from transformers import WhisperTokenizer


feature_extractor = WhisperFeatureExtractor.from_pretrained("openai/whisper-small")

tokenizer = WhisperTokenizer.from_pretrained("openai/whisper-small", language="Punjabi", task="transcribe")
# Out:
# preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/805 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/836k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.08k [00:00<?, ?B/s]

# %%
from transformers import WhisperProcessor

processor=WhisperProcessor.from_pretrained("openai/whisper-small", language="Punjabi", task="transcribe")

# %%
processor
# Out:
# WhisperProcessor:
# - feature_extractor: WhisperFeatureExtractor {
#   "chunk_length": 30,
#   "feature_extractor_type": "WhisperFeatureExtractor",
#   "feature_size": 80,
#   "hop_length": 160,
#   "n_fft": 400,
#   "n_samples": 480000,
#   "nb_max_frames": 3000,
#   "padding_side": "right",
#   "padding_value": 0.0,
#   "processor_class": "WhisperProcessor",
#   "return_attention_mask": false,
#   "sampling_rate": 16000
# }
#
# ...

# %%
print('| Check the random audio example from Common Voice dataset to see what form the data is in:')

print(f'{common_voice["train"][0]}\n')

from datasets import Audio
common_voice = common_voice.cast_column("audio", Audio(sampling_rate=16000))

print('| Check the effect of downsampling:')

print(f'{common_voice["train"][0]}\n')

def prepare_dataset(batch):
  audio = batch ["audio"]
  batch["input_features"] = feature_extractor(audio["array"], sampling_rate=audio["sampling_rate"]).input_features [0]
  batch["labels"] = tokenizer(batch["sentence"]).input_ids
  return batch


common_voice = common_voice.map(
    prepare_dataset, remove_columns=common_voice.column_names["train"],num_proc=2)# num_proc > 1 will enable multiprocessing
# Out:
# | Check the random audio example from Common Voice dataset to see what form the data is in:
# {'audio': {'path': '/root/.cache/huggingface/datasets/downloads/extracted/c015d2766ea512358e1fa9ad11a6eea73273b6851ab4f6d1d680587764e9f585/pa-IN_train_0/common_voice_pa-IN_23337849.mp3', 'array': array([0., 0., 0., ..., 0., 0., 0.]), 'sampling_rate': 48000}, 'sentence': 'ਕਲੱਬਾਂ ਦੇ ਬੈਨਰ ਲੱਗੇ ਹੋਏ ਸਨ'}
#
# | Check the effect of downsampling:
# {'audio': {'path': '/root/.cache/huggingface/datasets/downloads/extracted/c015d2766ea512358e1fa9ad11a6eea73273b6851ab4f6d1d680587764e9f585/pa-IN_train_0/common_voice_pa-IN_23337849.mp3', 'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         1.57673874e-12, -5.00932629e-13, -3.45390383e-13]), 'sampling_rate': 16000}, 'sentence': 'ਕਲੱਬਾਂ ਦੇ ਬੈਨਰ ਲੱਗੇ ਹੋਏ ਸਨ'}
# ...
# Map (num_proc=2):   0%|          | 0/399 [00:00<?, ? examples/s]

# %%
@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
  processor: Any
  def __call__(self, features: List [Dict[str, Union [List[int], torch.Tensor]]])  -> Dict[str, torch.Tensor]:
    input_features = [{"input_features": feature ["input_features"]} for feature in features]
    batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")
    label_features = [{"input_ids": feature["labels"]} for feature in features]
    labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")

    labels=labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1),-100)

    if (labels[:, 0]==self.processor.tokenizer.bos_token_id).all().cpu().item():
      labels=labels[:, 1:]
    batch["labels"]=labels
    return batch

data_collator=DataCollatorSpeechSeq2SeqWithPadding(processor=processor)

# %%
data_collator
# Out:
# DataCollatorSpeechSeq2SeqWithPadding(processor=WhisperProcessor:
# - feature_extractor: WhisperFeatureExtractor {
#   "chunk_length": 30,
#   "feature_extractor_type": "WhisperFeatureExtractor",
#   "feature_size": 80,
#   "hop_length": 160,
#   "n_fft": 400,
#   "n_samples": 480000,
#   "nb_max_frames": 3000,
#   "padding_side": "right",
#   "padding_value": 0.0,
#   "processor_class": "WhisperProcessor",
#   "return_attention_mask": false,
#   "sampling_rate": 16000
# }
#
# ...

# %%
import evaluate
metric=evaluate.load("wer")

# %%
metric
# Out:
# EvaluationModule(name: "wer", module_type: "metric", features: {'predictions': Value(dtype='string', id='sequence'), 'references': Value(dtype='string', id='sequence')}, usage: """
# Compute WER score of transcribed segments against references.
#
# Args:
#     references: List of references for each speech input.
#     predictions: List of transcriptions to score.
#     concatenate_texts (bool, default=False): Whether to concatenate all input texts or compute WER iteratively.
#
# Returns:
#     (float): the word error rate
#
# Examples:
#
#     >>> predictions = ["this is the prediction", "there is an other sample"]
#     >>> references = ["this is the reference", "there is another one"]
#     >>> wer = evaluate.load("wer")
#     >>> wer_score = wer.compute(predictions=predictions, references=references)
#     >>> print(wer_score)
#     0.5
# """, stored examples: 0)

# %%
from transformers import WhisperForConditionalGeneration

model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-small")
# Out:
# config.json:   0%|          | 0.00/1.97k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/967M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.84k [00:00<?, ?B/s]

# %%
model
# Out:
# WhisperForConditionalGeneration(
#   (model): WhisperModel(
#     (encoder): WhisperEncoder(
#       (conv1): Conv1d(80, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv2): Conv1d(768, 768, kernel_size=(3,), stride=(2,), padding=(1,))
#       (embed_positions): Embedding(1500, 768)
#       (layers): ModuleList(
#         (0-11): 12 x WhisperEncoderLayer(
#           (self_attn): WhisperAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=False)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
# ...

# %%
model.config.forced_decoder_ids=None
model.config.suppress_tokens=[]

# %%
from transformers import Seq2SeqTrainingArguments


training_args = Seq2SeqTrainingArguments(
    output_dir="./whisper-small-pa-IN",
    per_device_train_batch_size=1,
    gradient_accumulation_steps=2, # increase by 2x for every 2x decrease in batch size
    learning_rate=5e-5,
    warmup_steps=50,
    max_steps=3000,
    gradient_checkpointing=True,
    evaluation_strategy="steps",
    per_device_eval_batch_size=2,
    predict_with_generate=True,
    generation_max_length=225,
    save_steps=1000,
    eval_steps=1000,
    logging_steps=15,
    report_to=["tensorboard"],
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
    push_to_hub=False, # testing
)

# %%
#!pip install transformers[torch]

# %%
#!pip install accelerate -U

# %%
#!pip install transformers==4.9.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 22.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.7/212.7 kB 23.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for tokenizers
# Failed to build tokenizers
# ERROR: Could not build wheels for tokenizers, which is required to install pyproject.toml-based projects

# %%
# !pip install accelerate==0.20.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.5/227.5 kB 2.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.25.0
#     Uninstalling accelerate-0.25.0:
#       Successfully uninstalled accelerate-0.25.0
# ...

# %%
#!pip install accelerate>=0.20.1

# %%
from transformers import Seq2SeqTrainer

def compute_metrics(pred):
  pred_ids = pred.predictions
  label_ids=pred.label_ids
  pred_str = tokenizer.batch_decode(pred_ids, skip_special_tokens=True)
  label_str = tokenizer.batch_decode(label_ids, skip_special_tokens=True)
  wer = 100 * metric.compute(predictions=pred_str, references=label_str)
  return {"wer": wer}

trainer=Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=common_voice["train"],
    eval_dataset=common_voice["test"],
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=processor.feature_extractor,
)

# %%
print("Training is started")
trainer.train()
print("training endd")
# Out:
# Training is started
#     <div>
#
#       <progress value='3000' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3000/3000 1:48:05, Epoch 6/7]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>0.088700</td>
#       <td>0.372796</td>
#       <td>59.427966</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.027700</td>
#       <td>0.384441</td>
#       <td>48.163842</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.000200</td>
#       <td>0.421062</td>
#       <td>48.658192</td>
#     </tr>
#   </tbody>
# </table><p>
# ...

# %%
ls whisper-small-pa-IN
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-29-ac39a2c0c09a> in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('ls', 'whisper-small-pa-IN')
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/alias.py in __call__(self, rest)
#     184             cmd = '%s %s' % (cmd % tuple(args[:nargs]),' '.join(args[nargs:]))
#     185
# --> 186         self.shell.system(cmd)
#     187
#     188 #-----------------------------------------------------------------------------
#
# ...

# %% [markdown]
# FIRST EXECUTE TILL ABOVE

# %%
from transformers import pipeline, WhisperForConditionalGeneration

# Load the fine-tuned model from the local path
whisper_model = WhisperForConditionalGeneration.from_pretrained("/content/whisper-small-pa-IN", local_files_only=True)

# Create a pipeline for speech recognition
speech_recognition = pipeline(
    task="automatic-speech-recognition",
    model=whisper_model,
    tokenizer=processor.feature_extractor,
    device=0,  # Change this to the appropriate device (0 for GPU, -1 for CPU)
)

# Path to your Punjabi audio file
audio_file_path = "/content/WhatsApp Ptt 2023-12-15 at 10.23.06 PM.mp3"

# Transcribe the audio
transcription = speech_recognition(audio_file_path)

# Print the transcription
print("Transcription:", transcription[0]["sentence"])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-34-5d58507f8b97> in <cell line: 4>()
#       2
#       3 # Load the fine-tuned model from the local path
# ----> 4 whisper_model = WhisperForConditionalGeneration.from_pretrained("/content/whisper-small-pa-IN", local_files_only=True)
#       5
#       6 # Create a pipeline for speech recognition
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    2940         if not isinstance(config, PretrainedConfig):
#    2941             config_path = config if config is not None else pretrained_model_name_or_path
# -> 2942             config, model_kwargs = cls.config_class.from_pretrained(
# ...

# %%
# After fine-tuning, save the model
trainer.save_model("/content/whisper-small-pa-IN")

# Load the fine-tuned model
whisper_model = WhisperForConditionalGeneration.from_pretrained("/content/whisper-small-pa-IN", local_files_only=True)

# %%
processor.save_pretrained("/content/whisper-small-pa-IN")

# %%
# !pip install librosa
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-32-1b0d73217c55> in <cell line: 1>()
# ----> 1 get_ipython().system('pip install librosa')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
#     455       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     456   )
#
# ...

# %%
import numpy as np
import librosa
from transformers import pipeline, WhisperForConditionalGeneration, WhisperProcessor

# Load the fine-tuned model from the correct path
whisper_model = WhisperForConditionalGeneration.from_pretrained("/content/whisper-small-pa-IN", local_files_only=True)

# Load the processor that includes the feature extractor and tokenizer
processor = WhisperProcessor.from_pretrained("/content/whisper-small-pa-IN", language="Punjabi", task="transcribe")

# Load the audio file
file_path = "/content/WhatsApp Ptt 2023-12-15 at 10.23.06 PM.mp3"
audio_array, sampling_rate = librosa.load(file_path, sr=None)

# Create a dictionary with "raw" and "sampling_rate" keys
input_dict = {"raw": audio_array, "sampling_rate": sampling_rate}

# Use the processor to prepare the input features
input_features = processor.feature_extractor(input_dict["raw"], sampling_rate=input_dict["sampling_rate"]).input_features[0]

# Use the pipeline to transcribe the audio
result = pipeline(
    task="automatic-speech-recognition",
    model=whisper_model,
    feature_extractor=processor.feature_extractor,
    tokenizer=processor.tokenizer,
    device=0,  # Change this to the appropriate device (0 for GPU, -1 for CPU)
)(input_features)

# Print the transcription
print("Transcription:", result[0]["sentence"])
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-8dcc18501d7f> in <cell line: 19>()
#      17
#      18 # Use the processor to prepare the input features
# ---> 19 input_features = processor.feature_extractor(input_dict["raw"], sampling_rate=input_dict["sampling_rate"]).input_features[0]
#      20
#      21 # Use the pipeline to transcribe the audio
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/feature_extraction_whisper.py in __call__(self, raw_speech, truncation, pad_to_multiple_of, return_tensors, return_attention_mask, padding, max_length, sampling_rate, do_normalize, **kwargs)
#     193         if sampling_rate is not None:
#     194             if sampling_rate != self.sampling_rate:
# ...

# %%
import torch

# Assuming input_features is your original input with shape [1, 80, 18]
# You need to pad the last dimension to make it 3000

# Define the target length
target_length = 3000

# Pad the input features
padded_features = torch.nn.functional.pad(input_features, (0, target_length - input_features.shape[-1]))

# Now, padded_features will have shape [1, 80, 3000]

# %%
#finallllllllllllllllllllllllll

import numpy as np
import librosa
from transformers import WhisperProcessor, WhisperForConditionalGeneration

# Load the processor that includes the feature extractor and tokenizer
processor = WhisperProcessor.from_pretrained("/content/whisper-small-pa-IN", language="Punjabi", task="transcribe")

# Load the ASR model
whisper_model = WhisperForConditionalGeneration.from_pretrained("/content/whisper-small-pa-IN", local_files_only=True)

# Load the audio file with the correct sampling rate and force it to be mono (single-channel)
file_path = "/content/WhatsApp Ptt 2023-12-15 at 10.23.06 PM.mp3"
audio_array, sampling_rate = librosa.load(file_path, sr=16000, mono=True)  # Ensure mono=True for single-channel audio

# Use the processor to prepare the input features
inputs = processor(
    audio_array,
    sampling_rate=sampling_rate,
    return_tensors="pt",
    padding="max_length",
    max_length=3000,  # Set the max length to the expected sequence length
    truncation=True
)

# Extract the input features from the processed inputs
input_features = inputs["input_features"]

# Print the shape of the input features (optional)
print("Input features shape:", input_features.shape)

# Use the ASR model to transcribe the audio
result = whisper_model.generate(input_features)

# Decode the generated IDs to text
transcription = processor.batch_decode(result, skip_special_tokens=True)

# Print the transcription
print("Transcription:", transcription[0])
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Input features shape: torch.Size([1, 80, 18])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-2f7c270ccf44> in <cell line: 34>()
#      32
#      33 # Use the ASR model to transcribe the audio
# ---> 34 result = whisper_model.generate(input_features)
#      35
#      36 # Decode the generated IDs to text
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/modeling_whisper.py in generate(self, input_features, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, return_timestamps, task, language, is_multilingual, prompt_ids, num_segment_frames, return_token_timestamps, return_segments, attention_mask, time_precision, return_dict_in_generate, **kwargs)
# ...

# %%
import torch
import numpy as np
import librosa
from transformers import WhisperProcessor, WhisperForConditionalGeneration

# Load the processor that includes the feature extractor and tokenizer
processor = WhisperProcessor.from_pretrained("/content/whisper-small-pa-IN", language="Punjabi", task="transcribe")

# Load the ASR model
whisper_model = WhisperForConditionalGeneration.from_pretrained("/content/whisper-small-pa-IN", local_files_only=True)

# Load the audio file with the correct sampling rate and force it to be mono (single-channel)
file_path = "/content/WhatsApp Ptt 2023-12-15 at 10.23.06 PM.mp3"
audio_array, sampling_rate = librosa.load(file_path, sr=16000, mono=True)  # Ensure mono=True for single-channel audio

# Use the processor to prepare the input features
inputs = processor(
    audio_array,
    sampling_rate=sampling_rate,
    return_tensors="pt",
    truncation=True
)

# Get the input features
input_features = inputs["input_features"]

# Pad the input features to the desired length (3000)
target_length = 3000
input_features = torch.nn.functional.pad(input_features, (0, target_length - input_features.shape[-1]))

# Print the shape of the input features (optional)
print("Input features shape:", input_features.shape)

# Use the ASR model to transcribe the audio
result = whisper_model.generate(input_features)

# Decode the generated IDs to text
transcription = processor.batch_decode(result, skip_special_tokens=True)

# Print the transcription
print("Transcription:", transcription[0])
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Input features shape: torch.Size([1, 80, 3000])
# Transcription: ਮੇਰਾ ਨਾਮ ਹੀ ਸਵਾਤੀ ਮੇਰਾ ਯੋਗਦਾਂ ਤੁਹਾਡੇ ਬਰਭਾਵਲੂ ਬਧਾਉਣਦੀ ਸੰਭਾਵਨਾਦੇ ਸਕਦਾ ਹੈ ਰਿਕਵੱਡੇ ਦਰਸ਼ਕ ਸਵੂਰਦਾ

# %%
import numpy as np
import librosa
from transformers import WhisperProcessor, WhisperForConditionalGeneration

# Load the processor that includes the feature extractor and tokenizer
processor = WhisperProcessor.from_pretrained("/content/whisper-small-pa-IN", language="Punjabi", task="transcribe")

# Load the ASR model
whisper_model = WhisperForConditionalGeneration.from_pretrained("/content/whisper-small-pa-IN", local_files_only=True)

# Load the audio file with the correct sampling rate and force it to be mono (single-channel)
file_path = "/content/mono_file.wav"
audio_array, sampling_rate = librosa.load(file_path, sr=16000, mono=True)  # Ensure mono=True for single-channel audio

# Use the processor to prepare the input features
inputs = processor(
    audio_array,
    sampling_rate=sampling_rate,
    return_tensors="pt",
    padding="max_length",
    max_length=3000,  # Set the max length to the expected sequence length
    truncation=True
)

# Extract the input features from the processed inputs
input_features = inputs["input_features"]

# Ensure the correct shape by explicitly padding
padding_length = 3000 - input_features.shape[-1]
if padding_length > 0:
    input_features = F.pad(input_features, (0, padding_length))

# Print the shape of the input features (optional)
print("Input features shape:", input_features.shape)

# Use the ASR model to transcribe the audio
result = whisper_model.generate(input_features)

# Decode the generated IDs to text
transcription = processor.batch_decode(result, skip_special_tokens=True)

# Print the transcription
print("Transcription:", transcription[0])
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/transformers/feature_extraction_utils.py in get_feature_extractor_dict(cls, pretrained_model_name_or_path, **kwargs)
#     497                 # Load from local folder or from cache or download from model Hub and cache
# --> 498                 resolved_feature_extractor_file = cached_file(
#     499                     pretrained_model_name_or_path,
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     429         # Load from URL or cache if already cached
# ...

# %%
from pydub import AudioSegment

# Load stereo audio
audio = AudioSegment.from_file("/content/WhatsApp Ptt 2023-12-15 at 10.23.06 PM.wav", format="wav")

# Convert to mono
mono_audio = audio.set_channels(1)

# Export as mono
mono_audio.export("mono_file.wav", format="wav")
# Out:
# <_io.BufferedRandom name='mono_file.wav'>
